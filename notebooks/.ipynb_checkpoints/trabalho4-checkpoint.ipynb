# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as f
from pyspark.sql.functions import to_timestamp
from pyspark.sql.functions import regexp_replace

# %%
spark = SparkSession.builder.getOrCreate()

# %%
df = spark.read.option("encoding", "UTF-8").option("decode", "UTF-8").csv('../dataset/debate-tweets.tsv', sep='\t', inferSchema=True)

# %%
df.show(vertical=True)
# Out:
# -RECORD 0--------------------
#  _c0  | 522394422710136832
#  _c1  | @anacddd verdade,...
#  _c2  | -27.516566
#  _c3  | -48.646082
#  _c4  | False
#  _c5  | 522394422710136832
#  _c6  | 522394422710136832
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | 3.0342583E8
#  _c10 | pt
#  _c11 | Biguaçu
#  _c12 | 77c15e08a456c529
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Geovana Nunes
#  _c26 | 295414968
#  _c27 | 295414968
#  _c28 | null
#  _c29 | 316
#  _c30 | Mon May 09 00:12:...
#  _c31 | geovanannunes
# -RECORD 1--------------------
#  _c0  | 522394422806581248
#  _c1  | Que ñ*
#  _c2  | -27.768328
#  _c3  | -51.668323
#  _c4  | False
#  _c5  | 522394422806581248
#  _c6  | 522394422806581248
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | es
#  _c11 | Cacique Doble
#  _c12 | 8e601ce139d21469
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Rosane Fernandes
#  _c26 | 2409363642
#  _c27 | 2409363642
#  _c28 | Cacique Doble RS
#  _c29 | 47
#  _c30 | Mon Mar 24 18:06:...
#  _c31 | Rosane_fsf
# -RECORD 2--------------------
#  _c0  | 522394422731100160
#  _c1  | Vou quebrar a Bruna
#  _c2  | -27.00464
#  _c3  | -48.623519
#  _c4  | False
#  _c5  | 522394422731100160
#  _c6  | 522394422731100160
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Balneário Camboriú
#  _c12 | f0849ab7d3658fec
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Bebel
#  _c26 | 162447082
#  _c27 | 162447082
#  _c28 | null
#  _c29 | 513
#  _c30 | Sat Jul 03 18:03:...
#  _c31 | _isarenata
# -RECORD 3--------------------
#  _c0  | 522394422810783745
#  _c1  | agora vou p segun...
#  _c2  | -15.852082
#  _c3  | -47.961413
#  _c4  | False
#  _c5  | 522394422810783745
#  _c6  | 522394422810783745
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Brasília
#  _c12 | 5722ff20ba67083b
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | tatá
#  _c26 | 387694391
#  _c27 | 387694391
#  _c28 | null
#  _c29 | 347
#  _c30 | Sun Oct 09 14:19:...
#  _c31 | thayflausino
# -RECORD 4--------------------
#  _c0  | 522394423137943553
#  _c1  | Me sinto tão bem ...
#  _c2  | -3.755046
#  _c3  | -38.566769
#  _c4  | False
#  _c5  | 522394423137943553
#  _c6  | 522394423137943553
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Fortaleza
#  _c12 | d16815010421ff73
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Simone ♥ DDM's ♥
#  _c26 | 152792963
#  _c27 | 152792963
#  _c28 | Fortaleza/Ceará
#  _c29 | 719
#  _c30 | Sun Jun 06 22:15:...
#  _c31 | simoneesilva
# -RECORD 5--------------------
#  _c0  | 522394423188271104
#  _c1  | Eu estou aqui, de...
#  _c2  | -22.846869
#  _c3  | -43.30883
#  _c4  | False
#  _c5  | 522394423188271104
#  _c6  | 522394423188271104
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Rio de Janeiro
#  _c12 | 97bcdfca1a2dca59
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Gar6
#  _c26 | 749780077
#  _c27 | 749780077
#  _c28 | Rio de Janeiro
#  _c29 | 356
#  _c30 | Fri Aug 10 17:56:...
#  _c31 | juliagar6
# -RECORD 6--------------------
#  _c0  | 522394423238606848
#  _c1  | Quando vai embora...
#  _c2  | -22.904301
#  _c3  | -43.544403
#  _c4  | False
#  _c5  | 522394423238606848
#  _c6  | 522394423238606848
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Rio de Janeiro
#  _c12 | 97bcdfca1a2dca59
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Isa
#  _c26 | 2476253858
#  _c27 | 2476253858
#  _c28 | null
#  _c29 | 164
#  _c30 | Sun May 04 02:22:...
#  _c31 | isabelleecorrea
# -RECORD 7--------------------
#  _c0  | 522394423528022016
#  _c1  | @paynecaralhudo k...
#  _c2  | -23.509058
#  _c3  | -46.96892
#  _c4  | False
#  _c5  | 522394423528022016
#  _c6  | 522394423528022016
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | 5.18826601E8
#  _c10 | pt
#  _c11 | Itapevi
#  _c12 | a4b238d605105bc9
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Júlio Lessa ✌
#  _c26 | 324937648
#  _c27 | 324937648
#  _c28 | null
#  _c29 | 943
#  _c30 | Mon Jun 27 13:28:...
#  _c31 | SiempreCtgLS
# -RECORD 8--------------------
#  _c0  | 522394423632875521
#  _c1  | Conceição da Barr...
#  _c2  | -18.713338
#  _c3  | -40.405779
#  _c4  | False
#  _c5  | 522394423632875521
#  _c6  | 522394423632875521
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Nova Venécia
#  _c12 | c4741ab4c7255e4b
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | ♔Lu♔
#  _c26 | 536501962
#  _c27 | 536501962
#  _c28 | Nova Venécia-Es
#  _c29 | 82
#  _c30 | Sun Mar 25 17:45:...
#  _c31 | Hey_Marrenta
# -RECORD 9--------------------
#  _c0  | 522394424010362881
#  _c1  | @Maniavato te amo ♥
#  _c2  | -23.064705
#  _c3  | -45.717173
#  _c4  | False
#  _c5  | 522394424010362881
#  _c6  | 522394424010362881
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | 5.42665678E8
#  _c10 | es
#  _c11 | Caçapava
#  _c12 | 769b08f849827258
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | queen
#  _c26 | 1414028317
#  _c27 | 1414028317
#  _c28 | | no puteiro com ...
#  _c29 | 1911
#  _c30 | Wed May 08 22:50:...
#  _c31 | ButeraCertified
# -RECORD 10-------------------
#  _c0  | 522394424048091138
#  _c1  | Alg me curtindo rs ♡
#  _c2  | -29.727041
#  _c3  | -51.170724
#  _c4  | False
#  _c5  | 522394424048091138
#  _c6  | 522394424048091138
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | São Leopoldo
#  _c12 | 90f848c81726a961
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Morales
#  _c26 | 614617840
#  _c27 | 614617840
#  _c28 | null
#  _c29 | 287
#  _c30 | Thu Jun 21 22:03:...
#  _c31 | NeiFresno
# -RECORD 11-------------------
#  _c0  | 522394424010358784
#  _c1  | @MiiluAA No, porq...
#  _c2  | -31.056397
#  _c3  | -64.49657
#  _c4  | False
#  _c5  | 522394424010358784
#  _c6  | 522394424010358784
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | 1.590468224E9
#  _c10 | es
#  _c11 | Córdoba
#  _c12 | 0b79f7e718cb54b9
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Pol Vaso | CS#1
#  _c26 | 363134917
#  _c27 | 363134917
#  _c28 | Argentina
#  _c29 | 449
#  _c30 | Sat Aug 27 15:49:...
#  _c31 | PabloTabachiOk
# -RECORD 12-------------------
#  _c0  | 522394423741906944
#  _c1  | #EMABiggestFansJu...
#  _c2  | -25.46765
#  _c3  | -49.203674
#  _c4  | False
#  _c5  | 522394423741906944
#  _c6  | 522394423741906944
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | und
#  _c11 | Curitiba
#  _c12 | 6d5542f8d837770d
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Debora Drew
#  _c26 | 2419641235
#  _c27 | 2419641235
#  _c28 | null
#  _c29 | 290
#  _c30 | Sun Mar 30 23:05:...
#  _c31 | Debora_DrewJB
# -RECORD 13-------------------
#  _c0  | 522394424568213505
#  _c1  | @raizabatista dev...
#  _c2  | -22.601362
#  _c3  | -42.740524
#  _c4  | False
#  _c5  | 522394424568213505
#  _c6  | 522394424568213505
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | 1.49932694E8
#  _c10 | pt
#  _c11 | Cachoeiras de Macacu
#  _c12 | 6dcd18121724993e
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Juuh ✨
#  _c26 | 2388425074
#  _c27 | 2388425074
#  _c28 | Interior do Rio
#  _c29 | 144
#  _c30 | Thu Mar 06 13:54:...
#  _c31 | AnaPettini_Rock
# -RECORD 14-------------------
#  _c0  | 522394424920506368
#  _c1  | Me senti ate d fe...
#  _c2  | -28.268637
#  _c3  | -48.69402
#  _c4  | False
#  _c5  | 522394424920506368
#  _c6  | 522394424920506368
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Imbituba
#  _c12 | d3ae9be3bb02d623
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Gabi Figueredo
#  _c26 | 179152256
#  _c27 | 179152256
#  _c28 | Imbituba
#  _c29 | 233
#  _c30 | Mon Aug 16 16:48:...
#  _c31 | gabrielafnunes
# -RECORD 15-------------------
#  _c0  | 522394424811458560
#  _c1  | qual o sentido de...
#  _c2  | -22.913742
#  _c3  | -43.222002
#  _c4  | False
#  _c5  | 522394424811458560
#  _c6  | 522394424811458560
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Rio de Janeiro
#  _c12 | 97bcdfca1a2dca59
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | rafa
#  _c26 | 1038510385
#  _c27 | 1038510385
#  _c28 | Rio de Janeiro
#  _c29 | 209
#  _c30 | Thu Dec 27 01:22:...
#  _c31 | costarafaella_
# -RECORD 16-------------------
#  _c0  | 522394425029574656
#  _c1  | I'm at Lava Rápid...
#  _c2  | -23.434559
#  _c3  | -46.7281
#  _c4  | False
#  _c5  | 522394425029574656
#  _c6  | 522394425029574656
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | es
#  _c11 | São Paulo
#  _c12 | 68e019afec7d0ba5
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Wagner Silva
#  _c26 | 2792115102
#  _c27 | 2792115102
#  _c28 | null
#  _c29 | 1201
#  _c30 | Fri Sep 05 15:18:...
#  _c31 | waguinhow1
# -RECORD 17-------------------
#  _c0  | 522394425121841153
#  _c1  | Fica comentando m...
#  _c2  | -22.950363
#  _c3  | -43.362201
#  _c4  | False
#  _c5  | 522394425121841153
#  _c6  | 522394425121841153
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Rio de Janeiro
#  _c12 | 97bcdfca1a2dca59
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | My eternal prince ♡
#  _c26 | 2366912339
#  _c27 | 2366912339
#  _c28 | Brazilian
#  _c29 | 64
#  _c30 | Wed Feb 26 12:48:...
#  _c31 | byaa_guedes
# -RECORD 18-------------------
#  _c0  | 522394425461579777
#  _c1  | "odeio que me man...
#  _c2  | -27.682631
#  _c3  | -48.774404
#  _c4  | False
#  _c5  | 522394425461579777
#  _c6  | 522394425461579777
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | pt
#  _c11 | Santo Amaro da Im...
#  _c12 | d74bdbd8c998ba77
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | ∆        jéfinhoW.♻
#  _c26 | 91805982
#  _c27 | 91805982
#  _c28 | FLORIANOPOLIS - SC
#  _c29 | 200
#  _c30 | Sun Nov 22 15:12:...
#  _c31 | JEHTRANSANTE
# -RECORD 19-------------------
#  _c0  | 522394425960701952
#  _c1  | CAMAMTEBABILONFRA...
#  _c2  | -26.32959
#  _c3  | -48.904965
#  _c4  | False
#  _c5  | 522394425960701952
#  _c6  | 522394425960701952
#  _c7  | Wed Oct 15 14:31:...
#  _c8  | 2014-10-15
#  _c9  | null
#  _c10 | sl
#  _c11 | Joinville
#  _c12 | 012d81605af0416c
#  _c13 | 0.0
#  _c14 | 0.0
#  _c15 | 0.0
#  _c16 | 0.0
#  _c17 | 0.0
#  _c18 | 0.0
#  _c19 | 0.0
#  _c20 | 0.0
#  _c21 | null
#  _c22 | null
#  _c23 | null
#  _c24 | null
#  _c25 | Barão
#  _c26 | 1257698580
#  _c27 | 1257698580
#  _c28 | Morro da Macumba
#  _c29 | 190
#  _c30 | Sun Mar 10 18:52:...
#  _c31 | SCHOOLBOYGORDO
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: long (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: double (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: double (nullable = true)
#  |-- _c14: double (nullable = true)
#  |-- _c15: double (nullable = true)
#  |-- _c16: double (nullable = true)
#  |-- _c17: double (nullable = true)
#  |-- _c18: double (nullable = true)
#  |-- _c19: double (nullable = true)
#  |-- _c20: string (nullable = true)
#  |-- _c21: string (nullable = true)
#  |-- _c22: long (nullable = true)
#  |-- _c23: string (nullable = true)
#  |-- _c24: string (nullable = true)
#  |-- _c25: string (nullable = true)
#  |-- _c26: string (nullable = true)
#  |-- _c27: long (nullable = true)
#  |-- _c28: string (nullable = true)
#  |-- _c29: string (nullable = true)
#  |-- _c30: string (nullable = true)
#  |-- _c31: string (nullable = true)

# %% [markdown]
# ## Questão 1:
#
# ### a)

# %%
df_time = df.withColumn('_c7', to_timestamp(f.split(df._c7, ' ')[3], 'HH:mm:ss'))

# %%
wordCountMorning = df_time.withColumn('word', f.explode(f.split(regexp_replace(f.upper(df_time._c1), '[\$,!"”]', ''), ' ')))\
    .where("_c7 between '1970-01-01 06:00:01' AND '1970-01-01 12:00:00'")\
    .where("word like '#%'")\
    .groupBy('word')\
    .count()\
    .sort('count', ascending=False)

# %%
wordCountAfternoon = df_time.withColumn('word', f.explode(f.split(regexp_replace(f.upper(df_time._c1), '[\$,!"”]', ''), ' ')))\
    .where("_c7 between '1970-01-01 12:00:01' AND '1970-01-01 18:00:00'")\
    .where("word like '#%'")\
    .groupBy('word')\
    .count()\
    .sort('count', ascending=False)

# %%
wordCountNight = df_time.withColumn('word', f.explode(f.split(regexp_replace(f.upper(df_time._c1), '[\$,!"”]', ''), ' ')))\
    .where("_c7 between '1970-01-01 18:00:01' AND '1970-01-01 23:59:59'")\
    .where("word like '#%'")\
    .groupBy('word')\
    .count()\
    .sort('count', ascending=False)

# %%
wordCountDawn = df_time.withColumn('word', f.explode(f.split(regexp_replace(f.upper(df_time._c1), '[\$,!"”]', ''), ' ')))\
    .where("_c7 between '1970-01-01 00:00:01' AND '1970-01-01 06:00:00'")\
    .where("word like '#%'")\
    .groupBy('word')\
    .count()\
    .sort('count', ascending=False)

# %%
wordCountMorning.show(1)
# Out:
# +-----------------+-----+
# |             word|count|
# +-----------------+-----+
# |#EMABiggestFans1D|14757|
# +-----------------+-----+
# only showing top 1 row

# %%
wordCountAfternoon.show(1)
# Out:
# +-----------------+-----+
# |             word|count|
# +-----------------+-----+
# |#EMABiggestFans1D|58489|
# +-----------------+-----+
# only showing top 1 row

# %%
wordCountNight.show(1)
# Out:
# +-----------------+-----+
# |             word|count|
# +-----------------+-----+
# |#EMABiggestFans1D|64676|
# +-----------------+-----+
# only showing top 1 row

# %%
wordCountDawn.show(1)
# Out:
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |#EMABIGGESTFANSJU...|85159|
# +--------------------+-----+
# only showing top 1 row

# %% [markdown]
# ### b)

# %%
df_time = df.withColumn('_c8', to_timestamp(df._c8, 'yyyy-MM-dd'))

# %%
wordCount = df_time.withColumn('word', f.explode(f.split(regexp_replace(f.upper(df_time._c1), '[\$,!"”]', ''), ' ')))\
    .where("word like '#%'")\
    .groupBy('_c8', 'word')\
    .count()\
    .sort('count', ascending=False)

# %%
wordCount.show()
# Out:
# +-------------------+--------------------+-----+
# |                _c8|                word|count|
# +-------------------+--------------------+-----+
# |2014-10-16 00:00:00|   #EMABIGGESTFANS1D|68414|
# |2014-10-16 00:00:00|#EMABIGGESTFANSJU...|58811|
# |2014-10-17 00:00:00|#EMABIGGESTFANSJU...|49599|
# |2014-10-17 00:00:00|   #EMABIGGESTFANS1D|47701|
# |2014-10-15 00:00:00|   #EMABIGGESTFANS1D|34366|
# |2014-10-19 00:00:00|#EMABIGGESTFANSJU...|33508|
# |2014-10-19 00:00:00|   #EMABIGGESTFANS1D|29497|
# |2014-10-15 00:00:00|#EMABIGGESTFANSJU...|27998|
# |2014-10-18 00:00:00|#EMABIGGESTFANSJU...|27399|
# |2014-10-18 00:00:00|   #EMABIGGESTFANS1D|27200|
# |2014-10-16 00:00:00|       #CAMILASAYSHI|10635|
# |2014-10-20 00:00:00|#EMABIGGESTFANSJU...|10475|
# |2014-10-20 00:00:00|   #EMABIGGESTFANS1D| 7399|
# |2014-10-15 00:00:00|        #STEALMYGIRL| 6929|
# |2014-10-20 00:00:00|     #DEBATENARECORD| 4430|
# |2014-10-15 00:00:00|   #BIGPAYNODANCEOFF| 4062|
# |2014-10-16 00:00:00|        #DEBATENOSBT| 3692|
# |2014-10-16 00:00:00|    #CARTERSNEWVIDEO| 3292|
# |2014-10-17 00:00:00|         #QUERONOTVZ| 3146|
# |2014-10-19 00:00:00|#LUANSANTANANAHOR...| 3102|
# +-------------------+--------------------+-----+
# only showing top 20 rows

# %%
wordCount.filter('_c8 is not null').groupBy('_c8').agg(f.first("word"), f.max("count")).show();
# Out:
# +-------------------+--------------------+----------+
# |                _c8|         first(word)|max(count)|
# +-------------------+--------------------+----------+
# |2014-10-18 00:00:00|#EMABIGGESTFANSJU...|     27399|
# |2014-10-15 00:00:00|   #EMABIGGESTFANS1D|     34366|
# |2014-10-17 00:00:00|#EMABIGGESTFANSJU...|     49599|
# |2014-10-19 00:00:00|#EMABIGGESTFANSJU...|     33508|
# |2014-10-16 00:00:00|   #EMABIGGESTFANS1D|     68414|
# |2014-10-20 00:00:00|#EMABIGGESTFANSJU...|     10475|
# +-------------------+--------------------+----------+

# %% [markdown]
# ### c)

# %%
df_time = df.withColumn('_c7', f.date_trunc('hour',f.to_timestamp(f.concat(df._c8, f.lit(" "), f.split(df._c7, ' ')[3]), 'yyyy-MM-dd HH:mm:ss')))

# %%
df_time.select('_c7').filter('_c7 is not null').groupBy('_c7').count().sort('_c7').show(144)
# Out:
# +-------------------+------+
# |                _c7| count|
# +-------------------+------+
# |2014-10-15 14:00:00| 34378|
# |2014-10-15 15:00:00| 79157|
# |2014-10-15 16:00:00| 78353|
# |2014-10-15 17:00:00| 83950|
# |2014-10-15 18:00:00| 77713|
# |2014-10-15 19:00:00| 65095|
# |2014-10-15 20:00:00| 66813|
# |2014-10-15 21:00:00| 79270|
# |2014-10-15 22:00:00| 86030|
# |2014-10-15 23:00:00| 97574|
# |2014-10-16 00:00:00|110232|
# |2014-10-16 01:00:00|163338|
# |2014-10-16 02:00:00|176211|
# |2014-10-16 03:00:00|124599|
# |2014-10-16 04:00:00| 77743|
# |2014-10-16 05:00:00| 42661|
# |2014-10-16 06:00:00| 22228|
# |2014-10-16 07:00:00| 10157|
# |2014-10-16 08:00:00|  8327|
# |2014-10-16 09:00:00| 23616|
# |2014-10-16 10:00:00| 37528|
# |2014-10-16 11:00:00| 42716|
# |2014-10-16 12:00:00| 49156|
# |2014-10-16 13:00:00| 55958|
# |2014-10-16 14:00:00| 66154|
# |2014-10-16 15:00:00| 76891|
# |2014-10-16 16:00:00| 79276|
# |2014-10-16 17:00:00| 65824|
# |2014-10-16 18:00:00| 57098|
# |2014-10-16 19:00:00| 58547|
# |2014-10-16 20:00:00| 68148|
# |2014-10-16 21:00:00| 88473|
# |2014-10-16 22:00:00| 99443|
# |2014-10-16 23:00:00| 93350|
# |2014-10-17 00:00:00|107984|
# |2014-10-17 01:00:00|142770|
# |2014-10-17 02:00:00|153981|
# |2014-10-17 03:00:00|122205|
# |2014-10-17 04:00:00| 76951|
# |2014-10-17 05:00:00| 42222|
# |2014-10-17 06:00:00| 20985|
# |2014-10-17 07:00:00| 10695|
# |2014-10-17 08:00:00|  8016|
# |2014-10-17 09:00:00| 20559|
# |2014-10-17 10:00:00| 35147|
# |2014-10-17 11:00:00| 40918|
# |2014-10-17 12:00:00| 48140|
# |2014-10-17 13:00:00| 59851|
# |2014-10-17 14:00:00| 66972|
# |2014-10-17 15:00:00| 74748|
# |2014-10-17 16:00:00| 74909|
# |2014-10-17 17:00:00| 65007|
# |2014-10-17 18:00:00| 58841|
# |2014-10-17 19:00:00| 57831|
# |2014-10-17 20:00:00| 65602|
# |2014-10-17 21:00:00| 53146|
# |2014-10-17 22:00:00| 53497|
# |2014-10-17 23:00:00| 54053|
# |2014-10-18 00:00:00| 55404|
# |2014-10-18 01:00:00| 61050|
# |2014-10-18 02:00:00| 63501|
# |2014-10-18 03:00:00| 56562|
# |2014-10-18 04:00:00| 42778|
# |2014-10-18 05:00:00| 37148|
# |2014-10-18 06:00:00| 27473|
# |2014-10-18 07:00:00| 17724|
# |2014-10-18 08:00:00| 12108|
# |2014-10-18 09:00:00| 11539|
# |2014-10-18 10:00:00| 17456|
# |2014-10-18 11:00:00| 27491|
# |2014-10-18 12:00:00| 41485|
# |2014-10-18 13:00:00| 58383|
# |2014-10-18 14:00:00| 71402|
# |2014-10-18 15:00:00| 75206|
# |2014-10-18 16:00:00| 72334|
# |2014-10-18 17:00:00| 69001|
# |2014-10-18 18:00:00| 63700|
# |2014-10-18 19:00:00| 61727|
# |2014-10-18 20:00:00| 59165|
# |2014-10-18 21:00:00| 60665|
# |2014-10-18 22:00:00| 65102|
# |2014-10-18 23:00:00| 68663|
# |2014-10-19 00:00:00| 73049|
# |2014-10-19 01:00:00| 80626|
# |2014-10-19 02:00:00| 89885|
# |2014-10-19 03:00:00| 97575|
# |2014-10-19 04:00:00| 77489|
# |2014-10-19 05:00:00| 55958|
# |2014-10-19 06:00:00| 40591|
# |2014-10-19 07:00:00| 22988|
# |2014-10-19 08:00:00| 16698|
# |2014-10-19 09:00:00| 13707|
# |2014-10-19 10:00:00| 15743|
# |2014-10-19 11:00:00| 22588|
# |2014-10-19 12:00:00| 38047|
# |2014-10-19 13:00:00| 55888|
# |2014-10-19 14:00:00| 69949|
# |2014-10-19 15:00:00| 75866|
# |2014-10-19 16:00:00| 76299|
# |2014-10-19 17:00:00| 73534|
# |2014-10-19 18:00:00| 80192|
# |2014-10-19 19:00:00| 77265|
# |2014-10-19 20:00:00| 75453|
# |2014-10-19 21:00:00| 77033|
# |2014-10-19 22:00:00| 86629|
# |2014-10-19 23:00:00| 95083|
# |2014-10-20 00:00:00|123610|
# |2014-10-20 01:00:00|134555|
# |2014-10-20 02:00:00|124997|
# |2014-10-20 03:00:00| 92015|
# |2014-10-20 04:00:00| 57005|
# |2014-10-20 05:00:00| 29497|
# |2014-10-20 06:00:00| 14504|
# |2014-10-20 07:00:00|  4922|
# +-------------------+------+

# %%
dates = df_time.select('_c8').filter('_c7 is not null').distinct().collect()

# %%
for date in dates:
    diff_sec = df_time.where("_c8 = '{}'".format(date['_c8']))\
                    .sort('_c7', ascending=False).first()._c7 -\
    df_time.where("_c8 = '{}'".format(date['_c8'])).first()._c7
    
    value = df_time.select('_c8')\
        .filter('_c7 is not null')\
        .where("_c8 = '{}'".format(date['_c8']))\
        .groupBy('_c8').count().select('count').collect()[0]['count']
    
    print(date['_c8'], 3600*(value/diff_sec.seconds))
# Out:
# 2014-10-18 49878.36896260374
# 2014-10-16 70737.2353846688
# 2014-10-20 77489.27658628736
# 2014-10-19 62006.34266600308
# 2014-10-17 63126.98063634995
# 2014-10-15 79028.39038986184

# %% [markdown]
# ### d)

# %%
spark.stop()
